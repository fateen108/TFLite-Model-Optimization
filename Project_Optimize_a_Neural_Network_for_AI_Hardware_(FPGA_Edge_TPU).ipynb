# %% [markdown]
# <a href="https://colab.research.google.com/github/fateen108/TFLite-Model-Optimization/blob/main/Project_Optimize_a_Neural_Network_for_AI_Hardware_(FPGA_Edge_TPU).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import time

# Load pre-trained MobileNet model
model = tf.keras.applications.MobileNetV2(weights="imagenet")

# Convert model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model
with open("mobilenet.tflite", "wb") as f:
    f.write(tflite_model)

print("Model converted to TensorFlow Lite format!")
# Out:
# Saved artifact at '/tmp/tmphrvwop4k'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_312')
# Output Type:
#   TensorSpec(shape=(None, 1000), dtype=tf.float32, name=None)
# Captures:
#   135155372943952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372944912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372946064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372945488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372943760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372945296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448447632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448448016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372947024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372944144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448447440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448448784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448454928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448455312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448455696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448455504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448450704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448456848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448457232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448457616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448457424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448452624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448458768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448454544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448460688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448458384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448461264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448456464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354024848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354025424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354024656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354025616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354023312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354022928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354022544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354022736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354024464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354021392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354021008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354020624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354020816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354025808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354019472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354018704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354023696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354017552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354017168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354016784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354021776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354015632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354015248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354014864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354015056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354013712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354013328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354012944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354013136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354017936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354012176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354011408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354016016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354014096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347485328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347485712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347485520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347486864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347487248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347487440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457196496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457197072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457197264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457199952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457200336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457200720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457200528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457201872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457202256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457202640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457202448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457197648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457203792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457204176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457204560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457199568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457205712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457206096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457206480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457207632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457208016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457208400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457208208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457203408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457209552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457209936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457210320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457205328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457211472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457211088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457210704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457207248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457209168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350717840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350716880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350717648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350719376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350720144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350719952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350717072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350721296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350721680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350722064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350721872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350718992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350720912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350722832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350729360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350729744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350729552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350724752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350730896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350731280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350731664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350731472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350726672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350728592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444777424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350730512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350730128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444779344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444779728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444779536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444780880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444781264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444781648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444781456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444777232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444782800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444783184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444783568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444783376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444784720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444785104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444785488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444785296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444780496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444786640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444787024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444787408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444787216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444782416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444788560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444788944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444789328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444789136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444784336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444790480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444790864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444791248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444791056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444786256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444792400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444792016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444791632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444792976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444788176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444790096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444531664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444531472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444534736: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model converted to TensorFlow Lite format!

# %%
import numpy as np

# Load TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path="mobilenet.tflite")
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Generate a random input tensor with the correct shape
input_shape = input_details[0]['shape']
input_data = np.random.rand(*input_shape).astype(np.float32)

# Run inference & measure time
start_time = time.time()
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()
end_time = time.time()

# Compute latency
inference_time = (end_time - start_time) * 1000
print(f"Inference Time: {inference_time:.2f} ms")
# Out:
# Inference Time: 62.39 ms

# %%
# Apply quantization (reduces precision to int8)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert model again
tflite_quantized_model = converter.convert()

# Save quantized model
with open("mobilenet_quantized.tflite", "wb") as f:
    f.write(tflite_quantized_model)

print("Quantized model saved!")
# Out:
# Saved artifact at '/tmp/tmp4h5h3xuu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_312')
# Output Type:
#   TensorSpec(shape=(None, 1000), dtype=tf.float32, name=None)
# Captures:
#   135155372943952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372944912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372946064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372945488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372943760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372945296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448447632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448448016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372947024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155372944144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448449744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448451664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448447440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448453584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448448784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448454928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448455312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448455696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448455504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448450704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448456848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448457232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448457616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448457424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448452624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448458768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448454544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448460688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448458384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448461264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448456464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155448459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354024848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354025424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354024656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354025616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354023312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354022928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354022544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354022736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354024464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354021392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354021008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354020624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354020816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354025808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354019472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354018704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354023696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354017552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354017168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354016784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354021776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354015632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354015248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354014864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354015056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354013712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354013328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354012944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354013136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354017936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354012176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354011408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354016016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155354014096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347485328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347485712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347485520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347486864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347487248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347487440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457196496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457197072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155347486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457198608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457197264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457199952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457200336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457200720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457200528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457201872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457202256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457202640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457202448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457197648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457203792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457204176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457204560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457199568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457205712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457206096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457206480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457207632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457208016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457208400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457208208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457203408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457209552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457209936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457210320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457205328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457211472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457211088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457210704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457207248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155457209168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350717840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350716880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350717648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350719376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350720144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350719952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350717072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350721296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350721680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350722064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350721872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350723792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350718992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350725712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350720912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350727632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350722832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350729360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350729744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350729552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350724752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350730896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350731280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350731664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350731472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350726672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350728592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444777424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350730512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155350730128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444779344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444779728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444779536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444780880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444781264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444781648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444781456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444777232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444782800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444783184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444783568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444783376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444778576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444784720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444785104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444785488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444785296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444780496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444786640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444787024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444787408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444787216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444782416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444788560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444788944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444789328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444789136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444784336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444790480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444790864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444791248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444791056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444786256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444792400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444792016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444791632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444792976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444788176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444790096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444531664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444531472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135155444534736: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Quantized model saved!

# %%
import os

# Get file sizes
original_size = os.path.getsize("mobilenet.tflite") / 1024 / 1024  # Convert to MB
quantized_size = os.path.getsize("mobilenet_quantized.tflite") / 1024 / 1024  # Convert to MB

print(f"Original Model Size: {original_size:.2f} MB")
print(f"Quantized Model Size: {quantized_size:.2f} MB")
# Out:
# Original Model Size: 13.34 MB
# Quantized Model Size: 3.62 MB

# %%
# Load quantized model
interpreter_q = tf.lite.Interpreter(model_path="mobilenet_quantized.tflite")
interpreter_q.allocate_tensors()

# Measure inference time for quantized model
start_time = time.time()
interpreter_q.set_tensor(input_details[0]['index'], input_data)
interpreter_q.invoke()
end_time = time.time()

inference_time_q = (end_time - start_time) * 1000
print(f"Quantized Inference Time: {inference_time_q:.2f} ms")
# Out:
# Quantized Inference Time: 21.13 ms
